# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902221-6invertstart.dcat_0016.xlsx", sheet_name='DCAT Data', index_col = 1)
df1 = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902228-6invertstart.DCAT_0032.xlsx", sheet_name='DCAT Data', index_col = 0)
# Out:
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default

# %%
df = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902221-1hotstart.dcat_0009.xlsx", sheet_name='DCAT Data', index_col = 1)
df1 = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902228-1hotstart.DCAT_0024.xlsx", sheet_name='DCAT Data', index_col = 0)
# Out:
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default

# %%
df = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902221-4turndown.dcat_0012.xlsx", sheet_name='DCAT Data', index_col = 1)
df1 = pd.read_excel(r"C:\Users\changl3\Downloads\OneDrive_1_10-17-2024\4269251902228-4turndown.DCAT_0027.xlsx", sheet_name='DCAT Data', index_col = 0)
# Out:
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default
#
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning:
#
# Workbook contains no default style, apply openpyxl's default

# %%
df = pd.read_excel(r"C:\Users\changl3\OneDrive - Carrier Corporation\02_projects\13_meta\data\bomac_SCF\4269251902221-srtest.dcat_0015.xlsx", sheet_name='DCAT Data', index_col = 1)
df1 = pd.read_excel(r"C:\Users\changl3\OneDrive - Carrier Corporation\02_projects\13_meta\data\bomac_SCF\4269251902228-srtest.DCAT_0031.xlsx", sheet_name='DCAT Data', index_col = 0)
# Out:
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\changl3\AppData\Local\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df = pd.read_excel(r"C:\Users\changl3\OneDrive - Carrier Corporation\02_projects\13_meta\data\bomac_SCF\4269251902221-wfrc.dcat_0014.xlsx", sheet_name='DCAT Data', index_col = 1)
df1 = pd.read_excel(r"C:\Users\changl3\OneDrive - Carrier Corporation\02_projects\13_meta\data\bomac_SCF\4269251902228-wfrc.DCAT_0030.xlsx", sheet_name='DCAT Data', index_col = 0)

# %%
df1.index = pd.to_datetime(df1.index, format='%I:%M:%S %p')
df.index = pd.to_datetime(df.index, format='%I:%M:%S %p')

# %%
# df.index
# Out:
# DatetimeIndex([                'NaT', '1900-01-01 22:34:51',
#                '1900-01-01 22:34:54', '1900-01-01 22:34:57',
#                '1900-01-01 22:35:00', '1900-01-01 22:35:03',
#                '1900-01-01 22:35:05', '1900-01-01 22:35:07',
#                '1900-01-01 22:35:10', '1900-01-01 22:35:13',
#                ...
#                '1900-01-01 23:48:27', '1900-01-01 23:48:30',
#                '1900-01-01 23:48:33', '1900-01-01 23:48:35',
#                '1900-01-01 23:48:38', '1900-01-01 23:48:41',
#                '1900-01-01 23:48:44', '1900-01-01 23:48:47',
#                '1900-01-01 23:48:50', '1900-01-01 23:48:53'],
#               dtype='datetime64[ns]', name='Request Time', length=1578, freq=None)

# %%
# pd.to_datetime?

# %%
import plotly
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Update the plot table here to match your test file.
var_list = [
            [['ECW', 'LCW', 'ECDW', 'LCDW'], ['VFD_ACT','GV1_ACT'], ['act_reg']]
]
var_titles =  ['D LCDW/ECDW/ECW/LCW/', 'D GV/VFD', 'D surge_region',
               'U LCDW/ECDW/ECW/LCW/', 'U GV/VFD', 'U surge_region',
               'Power', 'HGBP', ''
          ]

# %%
row_num = len(var_list)
col_num = len(var_list[0])
fig = make_subplots(rows=row_num*3, cols=col_num, shared_xaxes='all', vertical_spacing=0.04, subplot_titles=var_titles)

for row_idx, row_list in enumerate(var_list):
    for col_idx, col_list in enumerate(row_list):
        for var in col_list:
            var = var
            fig.add_trace(go.Scatter(x=df.index, y=df[var], name=var), row=row_idx+1, col=col_idx+1)

for row_idx, row_list in enumerate(var_list):
    for col_idx, col_list in enumerate(row_list):
        for var in col_list:
            var = var
            fig.add_trace(go.Scatter(x=df1.index, y=df1[var], name=var), row=row_idx+1+row_num, col=col_idx+1)
            
fig.add_trace(go.Scatter(x=df1.index, y=df1['HGBP_ACT'], name=var), row=3, col=2)
fig.add_trace(go.Scatter(x=df1.index, y=df['HGBP_ACT'], name=var), row=3, col=2)

fig.add_trace(go.Scatter(x=df1.index, y=df1['KW_P'], name=var), row=3, col=1)
fig.add_trace(go.Scatter(x=df1.index, y=df['KW_P'], name=var), row=3, col=1)
            
fig.update_layout(height=800, width=1200)
fig.write_html('casesrc.html')
fig.show()
# Out:
# <div>                            <div id="40222173-8a27-422f-9bf2-1e0d7f094d1a" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40222173-8a27-422f-9bf2-1e0d7f094d1a")) {                    Plotly.newPlot(                        "40222173-8a27-422f-9bf2-1e0d7f094d1a",                        [{"name":"ECW","x":[null,"1900-01-01T19:55:35","1900-01-01T19:55:38","1900-01-01T19:55:39","1900-01-01T19:55:42","1900-01-01T19:55:43","1900-01-01T19:55:45","1900-01-01T19:55:48","1900-01-01T19:55:49","1900-01-01T19:55:52","1900-01-01T19:55:54","1900-01-01T19:55:56","1900-01-01T19:55:58","1900-01-01T19:56:00","1900-01-01T19:56:02","1900-01-01T19:56:04","1900-01-01T19:56:06","1900-01-01T19:56:08","1900-01-01T19:56:10","1900-01-01T19:56:12","1900-01-01T19:56:14","
# ...
